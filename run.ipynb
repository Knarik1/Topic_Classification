# %%
# Preprocess data
# !python3 data_utils/preprocessing.py
# Out:
# train size  16692
# y_test size  4173
# y_train size  13353
# valid size  3339
# Folder train
# Loading data...
# Loading BERT tokenizer...
# df['text'] 13352
# 100%|█████████████████████████████████████| 13352/13352 [10:39<00:00, 20.89it/s]
# Saved to ./data/train/token_ids.json
# Saved to ./data/train/attention_masks.json
# Folder valid
# Loading data...
# Loading BERT tokenizer...
# df['text'] 3339
# 100%|███████████████████████████████████████| 3339/3339 [02:40<00:00, 20.80it/s]
# Saved to ./data/valid/token_ids.json
# Saved to ./data/valid/attention_masks.json
# Folder test
# Loading data...
# Loading BERT tokenizer...
# df['text'] 4173
# 100%|███████████████████████████████████████| 4173/4173 [03:17<00:00, 21.18it/s]
# Saved to ./data/test/token_ids.json
# Saved to ./data/test/attention_masks.json

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ! pip install aim
# ! pip install transformers

# %%
# !python3 ./drive/MyDrive/TopicClassification/main.py train --batch_size=32 --epochs=3 --learning_rate=2e-5 --model_path='./drive/MyDrive/TopicClassification/BERT_finetuned.pth' --cuda
# Out:
# 2021-08-09 02:08:05.341927: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# root        : INFO     Namespace(batch_size=32, cuda=True, epochs=3, learning_rate=2e-05, mode='train', model_path='./drive/MyDrive/TopicClassification/BERT_finetuned.pth', resume=False)
# root        : INFO     Using device cuda
# Train data size 13352
# Valid data size 3339
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# ...

# %%
# !python3 ./drive/MyDrive/TopicClassification/main.py test --batch_size=32 --model_path='./drive/MyDrive/TopicClassification/saved_models/BERT_finetuned.pth' --cuda
# Out:
# 2021-08-09 06:23:41.429883: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Test data size 4173
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...
